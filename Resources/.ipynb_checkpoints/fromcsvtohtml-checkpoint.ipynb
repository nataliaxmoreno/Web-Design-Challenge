# %%
import pandas as pd
from IPython.display import HTML
city_path = "city.csv"
citydata = pd.DataFrame(pd.read_csv(city_path)).set_index('City ID')
citydata
# Out:
#                 City  Cloudiness Country        Date  Humidity  Latitude  \
# City ID
# 0         Huayucachi          84      PE  1659415498        80  -12.1333
# 1           Barentin          87      FR  1659415498        94   49.5453
# 2           Bilibino          73      RU  1659415498        34   68.0546
# 3               Laas          97      IT  1659415498        82   46.6166
# 4            Mataura          10      NZ  1659415499        75  -46.1927
# ...              ...         ...     ...         ...       ...       ...
# 553        Sistranda          84      NO  1659415623        72   63.7256
# 554      Storforshei          75      NO  1659415623        81   66.4043
# 555       Borogontsy         100      RU  1659415623        97   62.6683
# 556          Kameoka          90      JP  1659415624        52   35.0000
# 557           Sabang         100      ID  1659415538        84    5.8933
#
#          Longitude  Temperature  Wind Speed
# City ID
# ...

# %%
result = citydata.to_html()
print(result)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Temperature</th>
#       <th>Wind Speed</th>
#     </tr>
#     <tr>
#       <th>City ID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Huayucachi</td>
#       <td>84</td>
#       <td>PE</td>
#       <td>1659415498</td>
#       <td>80</td>
#       <td>-12.1333</td>
#       <td>-75.2333</td>
#       <td>10.28</td>
#       <td>0.70</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Barentin</td>
#       <td>87</td>
#       <td>FR</td>
#       <td>1659415498</td>
#       <td>94</td>
# ...
